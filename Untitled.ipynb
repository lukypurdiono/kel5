# %%
import pandas as pd
import plotly.express as px
import json
import pickle
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from pyvis.network import Network
import re
import seaborn as sns
from typing_extensions import Literal, TypedDict
pd.set_option("display.max_columns", 32)

# %%
df_apbd = pd.read_excel("belanja_apbd_full.xlsx")

# %%
df_apbd.head()
# Out:
#    No             nama_pemda  Tahun      Ekonomi     Kesehatan   Ketertiban  \
# 0   1      Kab. Buton Tengah   2018  36919668025   53009867998   6467898200
# 1   2  Kab. Konawe Kepulauan   2018  38689971318   57325387949  11378008126
# 2   3        Kab. Aceh Barat   2018  84859343514  231532736991  15776065920
# 3   4   Kab. Aceh Barat Daya   2018  62241884784  136910382736   4897133048
# 4   5         Kab. Aceh Jaya   2018  68889006051  112109636390   5705840885
#
#    Lingkungan       ParBud     Pelayanan    Pendidikan       Sosial  \
# 0  3039732887   9294078750  120515410136  133536483005   8350526086
# 1  3948837073   6467292763  106948826054   76574062652   6075150545
# 2  8659030354  10312779967  145877249781  260930197229  30180770126
# 3   413243525            0  126493347044  173732308401   9812480831
# 4  7623624812   2516675103  152524960130  158388517011  26028831229
#
#     Rumah_Fasum  Populasi  Base_AHH  Target_AHH  Base_HLS  Target_HLS  \
# 0  166381245706   92165.0     67.17       69.97     12.32       12.35
# 1  134973917111   33680.0     67.88       71.99     11.30       11.59
# 2  143626171360  205971.0     67.62       67.72     14.57       14.58
# 3  146175506593  148111.0     64.51       64.65     13.55       13.56
# 4   94975152102   91087.0     66.77       66.88     13.95       13.96
#
#    Base_RLS  Target_RLS  Base_PPK  Target_PPK  Base_IPM  Target_IPM
# 0      7.02        7.28      7012        7016     62.82       63.46
# 1      8.90        9.17      6458        6601     63.44       64.36
# 2      9.04        9.08      8989        9134     70.20       70.47
# 3      8.12        8.13      7723        8093     65.09       65.67
# 4    813.00        8.37      8322        9262     68.07       68.83

# %%
df_apbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           695 non-null    int64
#  1   nama_pemda   695 non-null    object
#  2   Tahun        695 non-null    int64
#  3   Ekonomi      695 non-null    int64
#  4   Kesehatan    695 non-null    int64
#  5   Ketertiban   695 non-null    int64
#  6   Lingkungan   695 non-null    int64
#  7   ParBud       695 non-null    int64
#  8   Pelayanan    695 non-null    int64
#  9   Pendidikan   695 non-null    int64
#  10  Sosial       695 non-null    int64
#  11  Rumah_Fasum  695 non-null    int64
#  12  Populasi     695 non-null    float64
#  13  Base_AHH     695 non-null    float64
#  14  Target_AHH   695 non-null    float64
#  15  Base_HLS     695 non-null    float64
#  16  Target_HLS   695 non-null    float64
#  17  Base_RLS     695 non-null    float64
#  18  Target_RLS   695 non-null    float64
#  19  Base_PPK     695 non-null    int64
#  20  Target_PPK   695 non-null    int64
#  21  Base_IPM     695 non-null    float64
#  22  Target_IPM   695 non-null    float64
# dtypes: float64(9), int64(13), object(1)
# memory usage: 125.0+ KB

# %%
df_apbd.isna().sum()
# Out:
# No             0
# nama_pemda     0
# Tahun          0
# Ekonomi        0
# Kesehatan      0
# Ketertiban     0
# Lingkungan     0
# ParBud         0
# Pelayanan      0
# Pendidikan     0
# Sosial         0
# Rumah_Fasum    0
# Populasi       0
# Base_AHH       0
# Target_AHH     0
# Base_HLS       0
# Target_HLS     0
# Base_RLS       0
# Target_RLS     0
# Base_PPK       0
# Target_PPK     0
# Base_IPM       0
# Target_IPM     0
# dtype: int64

# %%
df_lokasi = pd.read_csv("daftar-nama-daerah.csv")

# %%
df_lokasi.head()
# Out:
#    nid  parent_nid                     name  serial  type  latitude  \
# 0    1           0            Provinsi Aceh      11     1  4.695135
# 1    2           0  Provinsi Sumatera Utara      12     1  2.115355
# 2    3           0  Provinsi Sumatera Barat      13     1 -0.739940
# 3    4           0            Provinsi Riau      14     1  0.293347
# 4    5           0           Provinsi Jambi      15     1 -1.485183
#
#     longitude  status
# 0   96.749399       1
# 1   99.545097       1
# 2  100.800005       1
# 3  101.706829       1
# 4  102.438058       1

# %%
df_lokasi.head()
# Out:
#    nid  parent_nid                     name  serial  type  latitude  \
# 0    1           0            Provinsi Aceh      11     1  4.695135
# 1    2           0  Provinsi Sumatera Utara      12     1  2.115355
# 2    3           0  Provinsi Sumatera Barat      13     1 -0.739940
# 3    4           0            Provinsi Riau      14     1  0.293347
# 4    5           0           Provinsi Jambi      15     1 -1.485183
#
#     longitude  status
# 0   96.749399       1
# 1   99.545097       1
# 2  100.800005       1
# 3  101.706829       1
# 4  102.438058       1

# %%
df_lokasi.isna().sum()
# Out:
# nid           0
# parent_nid    0
# name          0
# serial        0
# type          0
# latitude      0
# longitude     0
# status        0
# dtype: int64

# %%
df_lokasi = df_lokasi.rename(columns = {'name':'nama_pemda'})

# %%
data = pd.merge(df_lokasi,df_apbd,on= 'nama_pemda')

# %%
data.head()
# Out:
#    nid  parent_nid      nama_pemda  serial  type  latitude   longitude  \
# 0    1           0   Provinsi Aceh      11     1  4.695135   96.749399
# 1    1           0   Provinsi Aceh      11     1  4.695135   96.749399
# 2    4           0   Provinsi Riau      14     1  0.293347  101.706829
# 3    4           0   Provinsi Riau      14     1  0.293347  101.706829
# 4    5           0  Provinsi Jambi      15     1 -1.485183  102.438058
#
#    status   No  Tahun        Ekonomi      Kesehatan    Ketertiban  \
# 0       1  323   2018  1452817686869  1909701624088  154284281496
# 1       1  671   2019  1669151203228  2313841314896  205125897780
# 2       1  341   2018   421360380209   758832094731   40779867217
# 3       1  689   2019   467795868286   887612891883   53753502491
# 4       1  328   2018   316590899202   458373201774   36108097620
#
#      Lingkungan        ParBud      Pelayanan     Pendidikan        Sosial  \
# 0             0  196044123795  1691601699674  3010479876852  198946633810
# 1   16669568934  200647379457  1842269432502  3489530306759  224504640569
# 2  148502640661   73595311778  2220897812541  1887034877269   65423427306
# 3  150317412546   63876154956  2193115146149  1939266691369   71013549998
# 4   16925339839   29986311601   964304369809  1033522582032   50358210680
#
#      Rumah_Fasum   Populasi  Base_AHH  Target_AHH  Base_HLS  Target_HLS  \
# 0  2812146521839  5281314.0     69.52       69.64     14.13       14.27
# 1  2346360790961  5371532.0     69.64       69.87     14.27       14.30
# 2  1192762793962  6814909.0     70.99       71.19     13.03       13.11
# 3  1026362538372  6971745.0     71.19       71.48     13.11       13.14
# 4   618611162625  3570272.0     70.76       70.89     12.87       12.90
#
#    Base_RLS  Target_RLS  Base_PPK  Target_PPK  Base_IPM  Target_IPM
# 0      8.98        9.09      8957        9186     70.60       71.19
# 1      9.09        9.18      9186        9603     71.19       71.90
# 2      8.76        8.92     10677       10968     71.79       72.44
# 3      8.92        9.03     10968       11255     72.44       73.00
# 4      8.15        8.23      9880       10357     69.99       70.65

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 646 entries, 0 to 645
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nid          646 non-null    int64
#  1   parent_nid   646 non-null    int64
#  2   nama_pemda   646 non-null    object
#  3   serial       646 non-null    int64
#  4   type         646 non-null    int64
#  5   latitude     646 non-null    float64
#  6   longitude    646 non-null    float64
#  7   status       646 non-null    int64
#  8   No           646 non-null    int64
#  9   Tahun        646 non-null    int64
#  10  Ekonomi      646 non-null    int64
#  11  Kesehatan    646 non-null    int64
#  12  Ketertiban   646 non-null    int64
#  13  Lingkungan   646 non-null    int64
#  14  ParBud       646 non-null    int64
#  15  Pelayanan    646 non-null    int64
#  16  Pendidikan   646 non-null    int64
#  17  Sosial       646 non-null    int64
#  18  Rumah_Fasum  646 non-null    int64
#  19  Populasi     646 non-null    float64
#  20  Base_AHH     646 non-null    float64
#  21  Target_AHH   646 non-null    float64
#  22  Base_HLS     646 non-null    float64
#  23  Target_HLS   646 non-null    float64
#  24  Base_RLS     646 non-null    float64
#  25  Target_RLS   646 non-null    float64
#  26  Base_PPK     646 non-null    int64
#  27  Target_PPK   646 non-null    int64
#  28  Base_IPM     646 non-null    float64
#  29  Target_IPM   646 non-null    float64
# dtypes: float64(11), int64(18), object(1)
# memory usage: 156.5+ KB

# %%
df_data = data.copy()

# %%
df_data = df_data.drop(['parent_nid','serial','type','No'],axis=1)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 646 entries, 0 to 645
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nid          646 non-null    int64
#  1   nama_pemda   646 non-null    object
#  2   latitude     646 non-null    float64
#  3   longitude    646 non-null    float64
#  4   status       646 non-null    int64
#  5   Tahun        646 non-null    int64
#  6   Ekonomi      646 non-null    int64
#  7   Kesehatan    646 non-null    int64
#  8   Ketertiban   646 non-null    int64
#  9   Lingkungan   646 non-null    int64
#  10  ParBud       646 non-null    int64
#  11  Pelayanan    646 non-null    int64
#  12  Pendidikan   646 non-null    int64
#  13  Sosial       646 non-null    int64
#  14  Rumah_Fasum  646 non-null    int64
#  15  Populasi     646 non-null    float64
#  16  Base_AHH     646 non-null    float64
#  17  Target_AHH   646 non-null    float64
#  18  Base_HLS     646 non-null    float64
#  19  Target_HLS   646 non-null    float64
#  20  Base_RLS     646 non-null    float64
#  21  Target_RLS   646 non-null    float64
#  22  Base_PPK     646 non-null    int64
#  23  Target_PPK   646 non-null    int64
#  24  Base_IPM     646 non-null    float64
#  25  Target_IPM   646 non-null    float64
# dtypes: float64(11), int64(14), object(1)
# memory usage: 136.3+ KB

# %%
df_data.isna().sum()
# Out:
# nid            0
# nama_pemda     0
# latitude       0
# longitude      0
# status         0
# Tahun          0
# Ekonomi        0
# Kesehatan      0
# Ketertiban     0
# Lingkungan     0
# ParBud         0
# Pelayanan      0
# Pendidikan     0
# Sosial         0
# Rumah_Fasum    0
# Populasi       0
# Base_AHH       0
# Target_AHH     0
# Base_HLS       0
# Target_HLS     0
# Base_RLS       0
# Target_RLS     0
# Base_PPK       0
# Target_PPK     0
# Base_IPM       0
# Target_IPM     0
# dtype: int64

# %%
fig = px.scatter_mapbox(df_data, lat="latitude", lon="longitude", size="Target_IPM", color="Target_IPM",
                  color_continuous_scale=px.colors.sequential.YlGn, size_max=20,zoom=12,hover_name="nama_pemda")
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
import streamlit as st

# %%
df = pd.DataFrame(
     df_data["Target_IPM"],
     columns=['latitude', 'longitude'])

# %%
df_data.head()
# Out:
#    nid      nama_pemda  latitude   longitude  status  Tahun        Ekonomi  \
# 0    1   Provinsi Aceh  4.695135   96.749399       1   2018  1452817686869
# 1    1   Provinsi Aceh  4.695135   96.749399       1   2019  1669151203228
# 2    4   Provinsi Riau  0.293347  101.706829       1   2018   421360380209
# 3    4   Provinsi Riau  0.293347  101.706829       1   2019   467795868286
# 4    5  Provinsi Jambi -1.485183  102.438058       1   2018   316590899202
#
#        Kesehatan    Ketertiban    Lingkungan        ParBud      Pelayanan  \
# 0  1909701624088  154284281496             0  196044123795  1691601699674
# 1  2313841314896  205125897780   16669568934  200647379457  1842269432502
# 2   758832094731   40779867217  148502640661   73595311778  2220897812541
# 3   887612891883   53753502491  150317412546   63876154956  2193115146149
# 4   458373201774   36108097620   16925339839   29986311601   964304369809
#
#       Pendidikan        Sosial    Rumah_Fasum   Populasi  Base_AHH  \
# 0  3010479876852  198946633810  2812146521839  5281314.0     69.52
# 1  3489530306759  224504640569  2346360790961  5371532.0     69.64
# 2  1887034877269   65423427306  1192762793962  6814909.0     70.99
# 3  1939266691369   71013549998  1026362538372  6971745.0     71.19
# 4  1033522582032   50358210680   618611162625  3570272.0     70.76
#
#    Target_AHH  Base_HLS  Target_HLS  Base_RLS  Target_RLS  Base_PPK  \
# 0       69.64     14.13       14.27      8.98        9.09      8957
# 1       69.87     14.27       14.30      9.09        9.18      9186
# 2       71.19     13.03       13.11      8.76        8.92     10677
# 3       71.48     13.11       13.14      8.92        9.03     10968
# 4       70.89     12.87       12.90      8.15        8.23      9880
#
#    Target_PPK  Base_IPM  Target_IPM
# 0        9186     70.60       71.19
# 1        9603     71.19       71.90
# 2       10968     71.79       72.44
# 3       11255     72.44       73.00
# 4       10357     69.99       70.65

# %%
st.map(df)
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
